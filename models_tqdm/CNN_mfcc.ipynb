# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install patool
# Out:
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.3 MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12

# %% [markdown]
# #Generation Mode

# %%
import patoolib
patoolib.extract_archive("/content/drive/MyDrive/mfcc_split.rar", outdir="/content")
# Out:
# patool: Extracting /content/drive/MyDrive/mfcc.rar ...
# patool: running /usr/bin/unrar x -- /content/drive/MyDrive/mfcc.rar
# patool:     with cwd='/content'
# patool: ... /content/drive/MyDrive/mfcc.rar extracted to `/content'.
# '/content'

# %%
"""
Authors : Rayane KADEM
This programm is used to create a class that represents a black box model using tensorflox framework. :
    - The model conssists of  CNN layer, Fully connected layers and a softmax layer :
    - The CNN is used to extract features from spectrogram images and it contains :
        - 
        -

    - The output of CNN is flattened and fed into a fully connected layer with .. neurons
    - The output of fully connected layer is fed into a softmax layer with 10 neurons
"""

# Importing the required libraries
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from fetch_training_dataset_gen import fetch_spectogram_dataset
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
#import argparse
import keras
from keras.layers import Flatten, Dense, Dropout, Conv2D, Activation ,MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from keras.layers import LeakyReLU

# Defining the black box model
class CNNModel:
    def __init__(self):
        self.model = None
        self.model_name = "2layers_CNN_model2_mfcc_trial"
        self.model_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + ".h5"
        self.model_weights_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+  self.model_name + "_weights.h5"
        self.model_history_path_acc = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_acc.png"
        self.model_history_path_loss = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_loss.png"
        
        self.model_history = None
    
    def build_model(self):
        """
        This function is used to create the black box model :
        """
        # Defining the input layer
        
        model = Sequential()

        #Adding the CNN layers along with some drop outs and maxpooling
        model.add(Conv2D(64, (3,3), activation ='relu', input_shape = (288,432 , 3)))
        model.add(MaxPooling2D(pool_size = (2,2)))


        model.add(Conv2D(32, (3,3),strides=(1,1) , activation = 'relu'))
        model.add(MaxPooling2D(pool_size = (2,2)))
        
        model.add(Flatten())

        
        #Adding the dense layers
        model.add(Dense(256, activation = 'relu'))
        model.add(Dropout(0.5))
        model.add(Dense(124, activation = 'relu'))
        #final output layer with 10 predictions to be made
        model.add(Dense(10, activation = 'softmax'))
    
        
        
        # Compiling the model
        self.model = model
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.000005), loss='categorical_crossentropy', metrics=['accuracy'])

        
    def train_model(self, train_generator,validation_generator, epochs=10):
        """
        This function is used to train the black box model :
        """
        # Training the model
        self.model_history = self.model.fit(train_generator, epochs=epochs,validation_data=validation_generator, shuffle=True)

        
    def save_model(self):
        """
        This function is used to save the black box model :
        """
        # Save the model
        self.model.save(self.model_path)
        
    def load_model(self):
        """
        This function is used to load the black box model :
        """
        # Load the model
        self.model = tf.keras.models.load_model(self.model_path)
        
    def save_model_weights(self):
        """
        This function is used to save the weights of the black box model :
        """
        # Save the weights
        self.model.save_weights(self.model_weights_path)
    

    def evaluate_model(self, test_generator):
        """
        This function is used to evaluate the black box model :
        """
        # Evaluate the model
        test_loss, test_acc = self.model.evaluate(test_generator)
        print("Test loss: ", test_loss)
        print("Test accuracy: ", test_acc)
    
    def plot_model_history(self):
        """
        This function is used to plot the model history :
        """
        #define variables
        loss = self.model_history.history['loss']
        val_loss = self.model_history.history['val_loss']
        accuracy = self.model_history.history['accuracy']
        val_accuracy = self.model_history.history['val_accuracy']
        epochs = range(1, len(loss) + 1)
        # Plot the model history
        plt.figure()
        plt.plot(epochs, accuracy, label='Training accuracy')
        plt.plot(epochs, val_accuracy, label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.legend()
        plt.savefig(self.model_history_path_acc)
        plt.show()

        plt.figure()
        plt.plot(epochs, loss, label='Training loss')
        plt.plot(epochs, val_loss, label='Validation loss')
        plt.title('Training and validation loss')
        plt.legend()
        plt.savefig(self.model_history_path_loss)
        plt.show()
        
    def predict_class(self, spectrogram_image):
        """
        This function is used to predict the class of the spectrogram image :
        """
        # Predict the class
        prediction = self.model.predict(spectrogram_image)
        return np.argmax(prediction)

    def predict_classes(self, spectrogram_images):
        """
        This function is used to predict the classes of the spectrogram images :
        """
        # Predict the classes
        predictions = self.model.predict(spectrogram_images,10 // 10 + 1, verbose = 1)
        return np.argmax(predictions, axis=1)

    
    def plot_confusion_matrix(self, test_generator, classes=None):
        """
        This function is used to plot the confusion matrix :
        """
        # Predict the classes
        predictions = self.predict_classes(test_generator)
        # Plot the confusion matrix
        cm = confusion_matrix(test_generator.classes, predictions)
        if classes is None:
            classes = test_generator.class_indices.keys()
        plt.figure()
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(len(classes))
        plt.xticks(tick_marks, classes, rotation=45)
        plt.yticks(tick_marks, classes)
        fmt = 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()
        plt.savefig("/content/drive/MyDrive/Mymodels_result/"+ self.model_name +"/"+"confusion_matrix.png")
        plt.show()

def main():
    
    # Fetch the training and test dataset
    train_generator = fetch_spectogram_dataset("/content/mfcc/train")
    test_generator =  fetch_spectogram_dataset("/content/mfcc/test")
    validation_generator =  fetch_spectogram_dataset("/content/mfcc/validation")
    # Create the black box model
    black_box_model = CNNModel()
    
    # Build the black box model
    black_box_model.build_model()
    
    # Train the black box model
    black_box_model.train_model(train_generator,validation_generator, epochs=50)

    # Save the black box model
    black_box_model.save_model()

    # Evaluate the black box model
    black_box_model.evaluate_model(test_generator)

    # Plot the model history
    black_box_model.plot_model_history()
    
    # Plot the confusion matrix
    black_box_model.plot_confusion_matrix(test_generator)

if __name__ == "__main__":
    main()
# Out:
# Found 700 images belonging to 10 classes.
# Found 200 images belonging to 10 classes.
# Found 100 images belonging to 10 classes.
# Epoch 1/50
# Epoch 40/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.4891 - accuracy: 0.4957 - val_loss: 1.7538 - val_accuracy: 0.3900
# Epoch 41/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.4079 - accuracy: 0.5529 - val_loss: 1.8012 - val_accuracy: 0.3800
# Epoch 42/50
# 70/70 [==============================] - 8s 118ms/step - loss: 1.4102 - accuracy: 0.5429 - val_loss: 1.8091 - val_accuracy: 0.4100
# Epoch 43/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.3667 - accuracy: 0.5614 - val_loss: 1.6958 - val_accuracy: 0.3800
# Epoch 44/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.3940 - accuracy: 0.5357 - val_loss: 1.7243 - val_accuracy: 0.3900
# Epoch 45/50
# 70/70 [==============================] - 8s 118ms/step - loss: 1.3545 - accuracy: 0.5657 - val_loss: 1.7357 - val_accuracy: 0.4000
# Epoch 46/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.3588 - accuracy: 0.5686 - val_loss: 1.7524 - val_accuracy: 0.3900
# Epoch 47/50
# 70/70 [==============================] - 8s 120ms/step - loss: 1.3070 - accuracy: 0.5957 - val_loss: 1.7617 - val_accuracy: 0.3700
# Epoch 48/50
# 70/70 [==============================] - 8s 119ms/step - loss: 1.2851 - accuracy: 0.5929 - val_loss: 1.7560 - val_accuracy: 0.3700
# Epoch 49/50
# 70/70 [==============================] - 8s 118ms/step - loss: 1.2777 - accuracy: 0.6086 - val_loss: 1.7217 - val_accuracy: 0.3800
# Epoch 50/50
# 70/70 [==============================] - 8s 118ms/step - loss: 1.2516 - accuracy: 0.5914 - val_loss: 1.7521 - val_accuracy: 0.3900
# 20/20 [==============================] - 1s 54ms/step - loss: 1.8322 - accuracy: 0.3400
# Test loss:  1.8321548700332642
# Test accuracy:  0.3400000035762787
# 20/20 [==============================] - 1s 49ms/step

# %%
(6+13+2+1+18+18+10)/200
# Out:
# 0.34

# %% [markdown]
# #TQDM Mode

# %%
import patoolib
patoolib.extract_archive("/content/drive/MyDrive/mfcc.rar", outdir="/content")
# Out:
# patool: Extracting /content/drive/MyDrive/mfcc.rar ...
# patool: running /usr/bin/unrar x -- /content/drive/MyDrive/mfcc.rar
# patool:     with cwd='/content'
# patool: ... /content/drive/MyDrive/mfcc.rar extracted to `/content'.
# '/content'

# %%
"""
Authors : Rayane KADEM
In This program we use transfer learning with a pretrained vgg16model CNN model. We set the last 4
layers of the convolutional block to be re-trained, and we add 3 fully connected layers for the 
classifciation block. Vgg16 was trained previously on the well known ImageNet dataset. 
The presented architecture is inspired from a work of transfer learning for the task of writer 
identification with handwritten documents and yielded very promessing results. Which led us to test it
on the matter at hand.
"""

# Importing the required libraries
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Model
from fetch_training_dataset import fetch_spectogram_dataset
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import itertools
#import argparse
import keras
from keras.layers import Flatten, Dense, Dropout, Conv2D, Activation ,MaxPooling2D, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.applications.vgg16 import VGG16
from keras.callbacks import EarlyStopping
from fetch_training_dataset import prep_data_images

# %%
data = prep_data_images()
#data.prep_data("/content/mfcc",(224,124))
data.prep_data("/content/mfcc",None)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# country
#   0%|          | 0/100 [00:00<?, ?it/s]
#  13%|█▎        | 13/100 [00:00<00:00, 127.70it/s]
#  28%|██▊       | 28/100 [00:00<00:00, 139.09it/s]
#  44%|████▍     | 44/100 [00:00<00:00, 147.02it/s]
#  59%|█████▉    | 59/100 [00:00<00:00, 146.43it/s]
#  74%|███████▍  | 74/100 [00:00<00:00, 143.85it/s]
# 100%|██████████| 100/100 [00:00<00:00, 141.46it/s]
#  10%|█         | 1/10 [00:00<00:06,  1.40it/s]
# disco
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 155.98it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 151.15it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 149.20it/s]
#  63%|██████▎   | 63/100 [00:00<00:00, 144.78it/s]
#  78%|███████▊  | 78/100 [00:00<00:00, 144.22it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.09it/s]
#  20%|██        | 2/10 [00:01<00:05,  1.40it/s]
# hiphop
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 155.45it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 146.65it/s]
#  47%|████▋     | 47/100 [00:00<00:00, 143.17it/s]
#  62%|██████▏   | 62/100 [00:00<00:00, 140.61it/s]
#  77%|███████▋  | 77/100 [00:00<00:00, 140.76it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.14it/s]
#  30%|███       | 3/10 [00:02<00:05,  1.39it/s]
# blues
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 152.81it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 148.64it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 150.22it/s]
#  64%|██████▍   | 64/100 [00:00<00:00, 149.22it/s]
#  79%|███████▉  | 79/100 [00:00<00:00, 147.84it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.04it/s]
#  40%|████      | 4/10 [00:02<00:04,  1.40it/s]
# classical
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 156.70it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 152.51it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 152.37it/s]
#  64%|██████▍   | 64/100 [00:00<00:00, 149.95it/s]
#  80%|████████  | 80/100 [00:00<00:00, 149.16it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.72it/s]
#  50%|█████     | 5/10 [00:03<00:03,  1.41it/s]
# pop
#   0%|          | 0/100 [00:00<?, ?it/s]
#  15%|█▌        | 15/100 [00:00<00:00, 149.30it/s]
#  30%|███       | 30/100 [00:00<00:00, 140.18it/s]
#  45%|████▌     | 45/100 [00:00<00:00, 143.46it/s]
#  60%|██████    | 60/100 [00:00<00:00, 142.61it/s]
#  75%|███████▌  | 75/100 [00:00<00:00, 144.75it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.35it/s]
#  60%|██████    | 6/10 [00:04<00:02,  1.40it/s]
# rock
#   0%|          | 0/100 [00:00<?, ?it/s]
#  14%|█▍        | 14/100 [00:00<00:00, 138.26it/s]
#  29%|██▉       | 29/100 [00:00<00:00, 141.95it/s]
#  44%|████▍     | 44/100 [00:00<00:00, 141.33it/s]
#  60%|██████    | 60/100 [00:00<00:00, 144.78it/s]
#  75%|███████▌  | 75/100 [00:00<00:00, 145.55it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.21it/s]
#  70%|███████   | 7/10 [00:05<00:02,  1.39it/s]
# reggae
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 155.66it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 152.67it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 147.57it/s]
#  63%|██████▎   | 63/100 [00:00<00:00, 141.95it/s]
#  78%|███████▊  | 78/100 [00:00<00:00, 141.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 143.01it/s]
#  80%|████████  | 8/10 [00:05<00:01,  1.39it/s]
# jazz
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 154.28it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 150.00it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 151.40it/s]
#  64%|██████▍   | 64/100 [00:00<00:00, 146.90it/s]
#  79%|███████▉  | 79/100 [00:00<00:00, 147.90it/s]
# 100%|██████████| 100/100 [00:00<00:00, 142.79it/s]
#  90%|█████████ | 9/10 [00:06<00:00,  1.39it/s]
# metal
#   0%|          | 0/100 [00:00<?, ?it/s]
#  16%|█▌        | 16/100 [00:00<00:00, 157.69it/s]
#  32%|███▏      | 32/100 [00:00<00:00, 152.30it/s]
#  48%|████▊     | 48/100 [00:00<00:00, 149.14it/s]
#  63%|██████▎   | 63/100 [00:00<00:00, 147.70it/s]
#  78%|███████▊  | 78/100 [00:00<00:00, 147.69it/s]
# 100%|██████████| 100/100 [00:00<00:00, 147.24it/s]
# 100%|██████████| 10/10 [00:07<00:00,  1.40it/s]

# %%
width,height,dimension = data.Xtest[0].shape

# %%
width,height,dimension
# Out:
# (288, 432, 3)

# %% [markdown]
# ## Transfer learning Vgg16

# %%
# Defining the black box model
class CNNModel:
    def __init__(self):
        self.model = None
        self.model_name = "transfer_learning_vgg16_model_ADAM_crossEn_mfcc_2"
        self.model_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + ".h5"
        self.model_weights_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+  self.model_name + "_weights.h5"
        self.model_history_path_acc = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_acc.png"
        self.model_history_path_loss = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_loss.png"
        
        self.model_history = None
    
    def build_model(self):
        """
        This function is used to create the black box model :
        """
        # Defining the input layer
        
        model = Sequential()

        vggmodel=VGG16(include_top=False, weights='imagenet', input_tensor=None, input_shape=(width,height,dimension), pooling=None)
        
        # Take all weights of imagenet dataset except for last four layers
        for layer in vggmodel.layers[:-8]: 
            layer.trainable = False 

        x = vggmodel.output
        x = Flatten()(x)

        x = Dense(512, activation="relu")(x)
        x = Dropout(0.4)(x)
        x = Dense(128, activation="elu")(x)
        predictions = Dense(10, activation="softmax")(x)

        # creating the final model 
        model = Model( vggmodel.input, predictions)

        # Compiling the model
        self.model = model
        
        self.model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=0.00001), loss = "categorical_crossentropy", metrics=['accuracy'])
        return vggmodel, x
    def train_model(self,data, epochs=10):
        """
        This function is used to train the black box model :
        """
        # Training the model
        self.model_history = self.model.fit(data.Xtrain,data.ytrain, epochs=epochs,validation_data=(data.Xval,data.yval), shuffle=True)
        
    def save_model(self):
        """
        This function is used to save the black box model :
        """
        # Save the model
        self.model.save(self.model_path)
        
    def load_model(self):
        """
        This function is used to load the black box model :
        """
        # Load the model
        self.model = tf.keras.models.load_model(self.model_path)
        
    def save_model_weights(self):
        """
        This function is used to save the weights of the black box model :
        """
        # Save the weights
        self.model.save_weights(self.model_weights_path)
    

    def evaluate_model(self, Xtest,ytest):
        """
        This function is used to evaluate the black box model :
        """
        # Evaluate the model
        test_loss, test_acc = self.model.evaluate(Xtest,ytest)
        print("Test loss: ", test_loss)
        print("Test accuracy: ", test_acc)
    
    def plot_model_history(self):
        """
        This function is used to plot the model history :
        """
        #define variables
        loss = self.model_history.history['loss']
        val_loss = self.model_history.history['val_loss']
        accuracy = self.model_history.history['accuracy']
        val_accuracy = self.model_history.history['val_accuracy']
        epochs = range(1, len(loss) + 1)
        # Plot the model history
        plt.figure()
        plt.plot(epochs, accuracy, label='Training accuracy')
        plt.plot(epochs, val_accuracy, label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.legend()
        plt.savefig(self.model_history_path_acc)
        plt.show()

        plt.figure()
        plt.plot(epochs, loss, label='Training loss')
        plt.plot(epochs, val_loss, label='Validation loss')
        plt.title('Training and validation loss')
        plt.legend()
        plt.savefig(self.model_history_path_loss)
        plt.show()
        
    def predict_class(self, spectrogram_image):
        """
        This function is used to predict the class of the spectrogram image :
        """
        # Predict the class
        prediction = self.model.predict(spectrogram_image)
        return np.argmax(prediction)

    def predict_classes(self, spectrogram_images):
        """
        This function is used to predict the classes of the spectrogram images :
        """
        # Predict the classes
        predictions = self.model.predict(spectrogram_images)
        return np.argmax(predictions, axis=1)

    
    def plot_confusion_matrix(self, Xtest,ytest, classes=None):
        """
        This function is used to plot the confusion matrix :
        """
        # Predict the classes
        predictions = self.predict_classes(Xtest)
        # Plot the confusion matrix
        y_parse = np.argmax(ytest, axis=1)
        cm = confusion_matrix(y_parse, predictions)
        #if classes is None:
        #    classes = test_generator.class_indices.keys()
        plt.figure()
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(10)
        plt.xticks(tick_marks,classes,  rotation=45)
        plt.yticks(tick_marks,classes)
        fmt = 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()
        plt.savefig("/content/drive/MyDrive/Mymodels_result/"+ self.model_name +"/"+"confusion_matrix.png")
        plt.show()
        acc = np.diag(cm).sum() /cm.sum()
        print("acc",acc)

# %%
for i in range(1):
    
    # Fetch the training and test dataset
    
    # Create the  model
    model = CNNModel()
    
    # Build the  model
    vggmodel, model_features=model.build_model()
    # Train the  model
    model.train_model(data, epochs=30)
    
    # Save the  model
    model.save_model()

    # Evaluate  model
    model.evaluate_model(data.Xtest,data.ytest)

    # Plot the model history
    model.plot_model_history()
    
    # Plot the confusion matrix
    model.plot_confusion_matrix(data.Xtest,data.ytest)
# Out:
# Epoch 1/30
# 22/22 [==============================] - 32s 1s/step - loss: 2.0013 - accuracy: 0.2957 - val_loss: 1.6783 - val_accuracy: 0.3800
# Epoch 2/30
# 22/22 [==============================] - 28s 1s/step - loss: 1.5269 - accuracy: 0.4357 - val_loss: 1.5622 - val_accuracy: 0.3900
# Epoch 3/30
# 22/22 [==============================] - 28s 1s/step - loss: 1.2547 - accuracy: 0.5514 - val_loss: 1.5671 - val_accuracy: 0.4000
# Epoch 4/30
# 22/22 [==============================] - ETA: 0s - loss: 1.0650 - accuracy: 0.6314Epoch 5/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.9088 - accuracy: 0.7071 - val_loss: 1.2781 - val_accuracy: 0.5500
# Epoch 6/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.7202 - accuracy: 0.7657 - val_loss: 1.1728 - val_accuracy: 0.6200
# Epoch 7/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.6170 - accuracy: 0.7829 - val_loss: 1.2372 - val_accuracy: 0.6000
# Epoch 8/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.4667 - accuracy: 0.8457 - val_loss: 1.2005 - val_accuracy: 0.6300
# Epoch 9/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.3892 - accuracy: 0.8871 - val_loss: 1.5473 - val_accuracy: 0.5300
# Epoch 10/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.3122 - accuracy: 0.9000 - val_loss: 1.2782 - val_accuracy: 0.6000
# Epoch 11/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.2657 - accuracy: 0.9200 - val_loss: 1.3197 - val_accuracy: 0.5600
# Epoch 12/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.1863 - accuracy: 0.9471 - val_loss: 1.2421 - val_accuracy: 0.6900
# Epoch 13/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.1497 - accuracy: 0.9629 - val_loss: 1.2769 - val_accuracy: 0.6600
# Epoch 14/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.1385 - accuracy: 0.9686 - val_loss: 1.4018 - val_accuracy: 0.6600
# Epoch 15/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0893 - accuracy: 0.9814 - val_loss: 1.5278 - val_accuracy: 0.6300
# Epoch 16/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0829 - accuracy: 0.9843 - val_loss: 1.3100 - val_accuracy: 0.6500
# Epoch 17/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0804 - accuracy: 0.9814 - val_loss: 1.3630 - val_accuracy: 0.6400
# Epoch 18/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0590 - accuracy: 0.9857 - val_loss: 1.3699 - val_accuracy: 0.6800
# Epoch 19/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0411 - accuracy: 0.9943 - val_loss: 1.4260 - val_accuracy: 0.6300
# Epoch 20/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0541 - accuracy: 0.9871 - val_loss: 1.4238 - val_accuracy: 0.6700
# Epoch 21/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0488 - accuracy: 0.9900 - val_loss: 1.4724 - val_accuracy: 0.7200
# Epoch 22/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0464 - accuracy: 0.9914 - val_loss: 1.5238 - val_accuracy: 0.6800
# Epoch 23/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0334 - accuracy: 0.9929 - val_loss: 1.5157 - val_accuracy: 0.6400
# Epoch 24/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0144 - accuracy: 0.9971 - val_loss: 2.0308 - val_accuracy: 0.6200
# Epoch 25/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0289 - accuracy: 0.9929 - val_loss: 1.6148 - val_accuracy: 0.6200
# Epoch 26/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0183 - accuracy: 0.9957 - val_loss: 1.5603 - val_accuracy: 0.6800
# Epoch 27/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0206 - accuracy: 0.9971 - val_loss: 1.9025 - val_accuracy: 0.6600
# Epoch 28/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0347 - accuracy: 0.9900 - val_loss: 1.5962 - val_accuracy: 0.7000
# Epoch 29/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0254 - accuracy: 0.9943 - val_loss: 1.7357 - val_accuracy: 0.6600
# Epoch 30/30
# 22/22 [==============================] - 28s 1s/step - loss: 0.0533 - accuracy: 0.9886 - val_loss: 1.4262 - val_accuracy: 0.6400
# 7/7 [==============================] - 5s 695ms/step - loss: 1.2324 - accuracy: 0.6950
# Test loss:  1.2323986291885376
# Test accuracy:  0.6949999928474426
# acc 0.695

# %% [markdown]
# # VGG16+SVM

# %% [markdown]
# #VGG16 features + SVM

# %%
# Define feature extractor model
extractor = Model(model.model.input, model.model.layers[-2].output)
Xtrain = np.concatenate((data.Xtrain,data.Xval), axis=0)
# Feature extraction
xapp = extractor.predict(Xtrain) # training CNN features vector
xtest = extractor.predict(data.Xtest) # testing CNN features vector
# Normalisation
from sklearn import preprocessing 
""" MIN MAX SCALER """
min_max_scaler = preprocessing.MinMaxScaler(feature_range =(0, 1)) 
# Scaled feature 
xapp_n = min_max_scaler.fit_transform(xapp)
xtest_n = min_max_scaler.fit_transform(xtest)

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score
import pandas as pd
# transform labels to parse
yT  = np.argwhere(np.concatenate((data.ytrain,data.yval),axis=0))
yTr = yT[:,1] 
yT  = np.argwhere(data.ytest)
yTs = yT[:,1]

# %%
# function to find best accuracy and its related parameters Gamma and C
def best_value(tmbr,G,C):
  acc= tmbr.max()
  result = np.where(tmbr_all == acc)
  coor = list(zip(result[0], result[1]))
  g=G[coor[0][0]]
  c= C[coor[0][1]]
  return acc,g,c

# %%
#Grid search ofSVM

# Set a range for C values
C2 = np.array([100,200,500,1000,2015])
C1 = np.arange(1, 40,2)
C=np.append(C1,C2)
m=len(C)
# Set a range for Gamma values
G1 = np.array([0.00001,0.0001,0.001,0.01,0.1,0.2,0.5,1])  #
G2 = np.arange(2, 6, 1)  
G=np.append(G1,G2) 
n=len(G)

i=0
j=0
tmbr_all = np.zeros((n,m))
for C_value in C:
    for g_value in G:
    
        clf = svm.SVC(kernel='rbf', C=C_value, gamma=g_value)
        clf.fit(xapp_n, yTr)
        predicted = clf.predict(xtest_n)
        tmbr = accuracy_score(predicted,yTs)
        print(tmbr*100, C_value, g_value)
        tmbr_all[i,j] = tmbr
        i=i+1
    i=0
    j=j+1
acc, g,c = best_value(tmbr_all,G,C)
print("accuracy:", acc)
print("best params : gamma = ",g,",C =",c)
# Out:
# 8.5 1 1e-05
# 8.5 1 0.0001
# 35.0 1 0.001
# 69.5 1 0.01
# 69.5 1 0.1
# 70.0 1 0.2
# 66.5 1 0.5
# 45.0 1 1.0
# 25.0 1 2.0
# 11.5 1 3.0
# 10.5 1 4.0
# 9.0 1 5.0
# 8.5 3 1e-05
# 8.5 3 0.0001
# 70.5 3 0.001
# 70.0 3 0.01
# 69.5 3 0.1
# 68.5 3 0.2
# 66.5 3 0.5
# 45.5 3 1.0
# 26.0 3 2.0
# 12.5 3 3.0
# 11.0 3 4.0
# 10.5 3 5.0
# 8.5 5 1e-05
# 9.5 5 0.0001
# 71.0 5 0.001
# 70.0 5 0.01
# 69.0 5 0.1
# 69.5 5 0.2
# 66.5 5 0.5
# 45.5 5 1.0
# 26.0 5 2.0
# 12.5 5 3.0
# 11.0 5 4.0
# 10.5 5 5.0
# 8.5 7 1e-05
# 18.5 7 0.0001
# 70.5 7 0.001
# 69.5 7 0.01
# 69.5 7 0.1
# 69.5 7 0.2
# 66.5 7 0.5
# 45.5 7 1.0
# 26.0 7 2.0
# 12.5 7 3.0
# 11.0 7 4.0
# 10.5 7 5.0
# 8.5 9 1e-05
# 26.0 9 0.0001
# 70.0 9 0.001
# 70.5 9 0.01
# 70.0 9 0.1
# 69.5 9 0.2
# 66.5 9 0.5
# 45.5 9 1.0
# 26.0 9 2.0
# 12.5 9 3.0
# 11.0 9 4.0
# 10.5 9 5.0
# 8.5 11 1e-05
# 46.5 11 0.0001
# 69.0 11 0.001
# 70.5 11 0.01
# 70.0 11 0.1
# 69.5 11 0.2
# 66.5 11 0.5
# 45.5 11 1.0
# 26.0 11 2.0
# 12.5 11 3.0
# 11.0 11 4.0
# 10.5 11 5.0
# 8.5 13 1e-05
# 58.5 13 0.0001
# 69.5 13 0.001
# 71.0 13 0.01
# 69.5 13 0.1
# 69.5 13 0.2
# 66.5 13 0.5
# 45.5 13 1.0
# 26.0 13 2.0
# 12.5 13 3.0
# 11.0 13 4.0
# 10.5 13 5.0
# 8.5 15 1e-05
# 66.5 15 0.0001
# 69.0 15 0.001
# 71.0 15 0.01
# 69.5 15 0.1
# 69.5 15 0.2
# 66.5 15 0.5
# 45.5 15 1.0
# 26.0 15 2.0
# 12.5 15 3.0
# 11.0 15 4.0
# 10.5 15 5.0
# 8.5 17 1e-05
# 67.0 17 0.0001
# 69.0 17 0.001
# 71.0 17 0.01
# 69.5 17 0.1
# 69.5 17 0.2
# 66.5 17 0.5
# 45.5 17 1.0
# 26.0 17 2.0
# 12.5 17 3.0
# 11.0 17 4.0
# 10.5 17 5.0
# 8.5 19 1e-05
# 70.0 19 0.0001
# 70.0 19 0.001
# 71.0 19 0.01
# 69.5 19 0.1
# 69.5 19 0.2
# 66.5 19 0.5
# 45.5 19 1.0
# 26.0 19 2.0
# 12.5 19 3.0
# 11.0 19 4.0
# 10.5 19 5.0
# 8.5 21 1e-05
# 70.5 21 0.0001
# 69.5 21 0.001
# 71.0 21 0.01
# 69.5 21 0.1
# 69.5 21 0.2
# 66.5 21 0.5
# 45.5 21 1.0
# 26.0 21 2.0
# 12.5 21 3.0
# 11.0 21 4.0
# 10.5 21 5.0
# 8.5 23 1e-05
# 70.5 23 0.0001
# 70.0 23 0.001
# 71.0 23 0.01
# 69.5 23 0.1
# 69.5 23 0.2
# 66.5 23 0.5
# 45.5 23 1.0
# 26.0 23 2.0
# 12.5 23 3.0
# 11.0 23 4.0
# 10.5 23 5.0
# 8.5 25 1e-05
# 70.5 25 0.0001
# 70.0 25 0.001
# 70.5 25 0.01
# 69.5 25 0.1
# 69.5 25 0.2
# 66.5 25 0.5
# 45.5 25 1.0
# 26.0 25 2.0
# 12.5 25 3.0
# 11.0 25 4.0
# 10.5 25 5.0
# 8.5 27 1e-05
# 71.0 27 0.0001
# 70.0 27 0.001
# 70.0 27 0.01
# 69.5 27 0.1
# 69.5 27 0.2
# 66.5 27 0.5
# 45.5 27 1.0
# 26.0 27 2.0
# 12.5 27 3.0
# 11.0 27 4.0
# 10.5 27 5.0
# 8.5 29 1e-05
# 71.0 29 0.0001
# 70.0 29 0.001
# 70.0 29 0.01
# 69.5 29 0.1
# 69.5 29 0.2
# 66.5 29 0.5
# 45.5 29 1.0
# 26.0 29 2.0
# 12.5 29 3.0
# 11.0 29 4.0
# 10.5 29 5.0
# 8.5 31 1e-05
# 70.0 31 0.0001
# 69.5 31 0.001
# 70.0 31 0.01
# 69.5 31 0.1
# 69.5 31 0.2
# 66.5 31 0.5
# 45.5 31 1.0
# 26.0 31 2.0
# 12.5 31 3.0
# 11.0 31 4.0
# 10.5 31 5.0
# 8.5 33 1e-05
# 71.0 33 0.0001
# 69.5 33 0.001
# 70.0 33 0.01
# 69.5 33 0.1
# 69.5 33 0.2
# 66.5 33 0.5
# 45.5 33 1.0
# 26.0 33 2.0
# 12.5 33 3.0
# 11.0 33 4.0
# 10.5 33 5.0
# 8.5 35 1e-05
# 71.0 35 0.0001
# 69.5 35 0.001
# 70.0 35 0.01
# 69.5 35 0.1
# 69.5 35 0.2
# 66.5 35 0.5
# 45.5 35 1.0
# 26.0 35 2.0
# 12.5 35 3.0
# 11.0 35 4.0
# 10.5 35 5.0
# 8.5 37 1e-05
# 71.0 37 0.0001
# 69.5 37 0.001
# 71.0 37 0.01
# 69.5 37 0.1
# 69.5 37 0.2
# 66.5 37 0.5
# 45.5 37 1.0
# 26.0 37 2.0
# 12.5 37 3.0
# 11.0 37 4.0
# 10.5 37 5.0
# 8.5 39 1e-05
# 71.0 39 0.0001
# 69.5 39 0.001
# 70.0 39 0.01
# 69.5 39 0.1
# 69.5 39 0.2
# 66.5 39 0.5
# 45.5 39 1.0
# 26.0 39 2.0
# 12.5 39 3.0
# 11.0 39 4.0
# 10.5 39 5.0
# 35.0 100 1e-05
# 69.0 100 0.0001
# 71.0 100 0.001
# 69.0 100 0.01
# 69.5 100 0.1
# 69.5 100 0.2
# 66.5 100 0.5
# 45.5 100 1.0
# 26.0 100 2.0
# 12.5 100 3.0
# 11.0 100 4.0
# 10.5 100 5.0
# 70.0 200 1e-05
# 69.5 200 0.0001
# 71.0 200 0.001
# 68.5 200 0.01
# 69.5 200 0.1
# 69.5 200 0.2
# 66.5 200 0.5
# 45.5 200 1.0
# 26.0 200 2.0
# 12.5 200 3.0
# 11.0 200 4.0
# 10.5 200 5.0
# 71.0 500 1e-05
# 70.0 500 0.0001
# 69.0 500 0.001
# 68.5 500 0.01
# 69.5 500 0.1
# 69.5 500 0.2
# 66.5 500 0.5
# 45.5 500 1.0
# 26.0 500 2.0
# 12.5 500 3.0
# 11.0 500 4.0
# 10.5 500 5.0
# 69.0 1000 1e-05
# 71.0 1000 0.0001
# 69.0 1000 0.001
# 68.5 1000 0.01
# 69.5 1000 0.1
# 69.5 1000 0.2
# 66.5 1000 0.5
# 45.5 1000 1.0
# 26.0 1000 2.0
# 12.5 1000 3.0
# 11.0 1000 4.0
# 10.5 1000 5.0
# 69.5 2015 1e-05
# 71.0 2015 0.0001
# 68.5 2015 0.001
# 68.5 2015 0.01
# 69.5 2015 0.1
# 69.5 2015 0.2
# 66.5 2015 0.5
# 45.5 2015 1.0
# 26.0 2015 2.0
# 12.5 2015 3.0
# 11.0 2015 4.0
# 10.5 2015 5.0
# accuracy: 0.71
# best params : gamma =  1e-05 ,C = 500

# %% [markdown]
# ## 2 Layers CNN model

# %%
width,height,dimenstion = data.Xtrain[0].shape

# %%
# Defining the black box model
class CNNModel:
    def __init__(self):
        self.model = None
        self.model_name = "2layersCNN_ADAM_crossEn_mfcc_ADAM_CrossEnt"
        self.model_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + ".h5"
        self.model_weights_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+  self.model_name + "_weights.h5"
        self.model_history_path_acc = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_acc.png"
        self.model_history_path_loss = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_loss.png"
        
        self.model_history = None
    
    def build_model(self):
        """
        This function is used to create the black box model :
        """
        # Defining the input layer
        
        model = Sequential()

        #Adding the CNN layers along with some drop outs and maxpooling
        
        model.add(Conv2D(64, (3,3), activation ='relu', input_shape =(width,height,dimenstion)))
        model.add(MaxPooling2D(pool_size = (2,2)))


        model.add(Conv2D(32, (3,3),strides=(1,1) , activation = 'relu'))
        model.add(MaxPooling2D(pool_size = (2,2)))
        
        model.add(Flatten())

        
        #Adding the dense layers
        model.add(Dense(256, activation = 'relu'))
        model.add(Dropout(0.5))
        model.add(Dense(124, activation = 'relu'))
        #final output layer with 10 predictions to be made
        model.add(Dense(10, activation = 'softmax'))
    
        
        
        # Compiling the model
        self.model = model
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=['accuracy'])

    def train_model(self,data, epochs=10):
        """
        This function is used to train the black box model :
        """
        # Training the model
        self.model_history = self.model.fit(data.Xtrain,data.ytrain, epochs=epochs,validation_data=(data.Xval,data.yval), shuffle=True)
        
    def save_model(self):
        """
        This function is used to save the black box model :
        """
        # Save the model
        self.model.save(self.model_path)
        
    def load_model(self):
        """
        This function is used to load the black box model :
        """
        # Load the model
        self.model = tf.keras.models.load_model(self.model_path)
        
    def save_model_weights(self):
        """
        This function is used to save the weights of the black box model :
        """
        # Save the weights
        self.model.save_weights(self.model_weights_path)
    

    def evaluate_model(self, Xtest,ytest):
        """
        This function is used to evaluate the black box model :
        """
        # Evaluate the model
        test_loss, test_acc = self.model.evaluate(Xtest,ytest)
        print("Test loss: ", test_loss)
        print("Test accuracy: ", test_acc)
    
    def plot_model_history(self):
        """
        This function is used to plot the model history :
        """
        #define variables
        loss = self.model_history.history['loss']
        val_loss = self.model_history.history['val_loss']
        accuracy = self.model_history.history['accuracy']
        val_accuracy = self.model_history.history['val_accuracy']
        epochs = range(1, len(loss) + 1)
        # Plot the model history
        plt.figure()
        plt.plot(epochs, accuracy, label='Training accuracy')
        plt.plot(epochs, val_accuracy, label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.legend()
        plt.savefig(self.model_history_path_acc)
        plt.show()

        plt.figure()
        plt.plot(epochs, loss, label='Training loss')
        plt.plot(epochs, val_loss, label='Validation loss')
        plt.title('Training and validation loss')
        plt.legend()
        plt.savefig(self.model_history_path_loss)
        plt.show()
        
    def predict_class(self, spectrogram_image):
        """
        This function is used to predict the class of the spectrogram image :
        """
        # Predict the class
        prediction = self.model.predict(spectrogram_image)
        return np.argmax(prediction)

    def predict_classes(self, spectrogram_images):
        """
        This function is used to predict the classes of the spectrogram images :
        """
        # Predict the classes
        predictions = self.model.predict(spectrogram_images)
        return np.argmax(predictions, axis=1)

    
    def plot_confusion_matrix(self, Xtest,ytest, classes=None):
        """
        This function is used to plot the confusion matrix :
        """
        # Predict the classes
        predictions = self.predict_classes(Xtest)
        # Plot the confusion matrix
        y_parse = np.argmax(ytest, axis=1)
        cm = confusion_matrix(y_parse, predictions)
        #if classes is None:
        #    classes = test_generator.class_indices.keys()
        plt.figure()
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(10)
        plt.xticks(tick_marks,classes,  rotation=45)
        plt.yticks(tick_marks,classes)
        fmt = 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()
        plt.savefig("/content/drive/MyDrive/Mymodels_result/"+ self.model_name +"/"+"confusion_matrix.png")
        plt.show()
        acc = np.diag(cm).sum() /cm.sum()
        print("acc",acc)

# %%
for i in range(1):
    
    # Fetch the training and test dataset
    
    # Create the  model
    model = CNNModel()
    
    # Build the  model
    model.build_model()
    # Train the  model
    model.train_model(data, epochs=150)
    
    # Save the  model
    model.save_model()

    # Evaluate  model
    model.evaluate_model(data.Xtest,data.ytest)

    # Plot the model history
    model.plot_model_history()
    
    # Plot the confusion matrix
    model.plot_confusion_matrix(data.Xtest,data.ytest)
# Out:
# Epoch 1/150
# 22/22 [==============================] - 18s 376ms/step - loss: 2.3260 - accuracy: 0.1243 - val_loss: 2.2634 - val_accuracy: 0.1200
# Epoch 2/150
# 22/22 [==============================] - 6s 270ms/step - loss: 2.2898 - accuracy: 0.1386 - val_loss: 2.2443 - val_accuracy: 0.1600
# Epoch 3/150
# 22/22 [==============================] - 6s 272ms/step - loss: 2.2449 - accuracy: 0.1900 - val_loss: 2.2055 - val_accuracy: 0.2600
# Epoch 4/150
# 22/22 [==============================] - 6s 270ms/step - loss: 2.1807 - accuracy: 0.2357 - val_loss: 2.1621 - val_accuracy: 0.3000
# Epoch 5/150
# 22/22 [==============================] - 6s 273ms/step - loss: 2.1151 - accuracy: 0.2914 - val_loss: 2.1233 - val_accuracy: 0.2700
# Epoch 6/150
# 22/22 [==============================] - 6s 271ms/step - loss: 2.0803 - accuracy: 0.2900 - val_loss: 2.0770 - val_accuracy: 0.2900
# Epoch 7/150
# 22/22 [==============================] - 6s 272ms/step - loss: 2.0382 - accuracy: 0.3029 - val_loss: 2.0477 - val_accuracy: 0.3700
# Epoch 8/150
# 22/22 [==============================] - 6s 272ms/step - loss: 1.9686 - accuracy: 0.3614 - val_loss: 1.9923 - val_accuracy: 0.3800
# Epoch 9/150
# 22/22 [==============================] - 6s 273ms/step - loss: 1.9276 - accuracy: 0.3700 - val_loss: 1.9770 - val_accuracy: 0.3800
# Epoch 10/150
# 22/22 [==============================] - 6s 272ms/step - loss: 1.8770 - accuracy: 0.3886 - val_loss: 1.9579 - val_accuracy: 0.3500
150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0536 - accuracy: 0.9929 - val_loss: 1.5030 - val_accuracy: 0.5300
# Epoch 140/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0627 - accuracy: 0.9900 - val_loss: 1.4426 - val_accuracy: 0.4900
# Epoch 141/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0567 - accuracy: 0.9914 - val_loss: 1.3889 - val_accuracy: 0.5300
# Epoch 142/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0699 - accuracy: 0.9914 - val_loss: 1.3863 - val_accuracy: 0.5400
# Epoch 143/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0727 - accuracy: 0.9900 - val_loss: 1.4366 - val_accuracy: 0.5200
# Epoch 144/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0578 - accuracy: 0.9943 - val_loss: 1.4525 - val_accuracy: 0.5300
# Epoch 145/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0556 - accuracy: 0.9900 - val_loss: 1.4816 - val_accuracy: 0.5200
# Epoch 146/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0571 - accuracy: 0.9914 - val_loss: 1.5086 - val_accuracy: 0.5400
# Epoch 147/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0544 - accuracy: 0.9929 - val_loss: 1.4376 - val_accuracy: 0.5200
# Epoch 148/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0456 - accuracy: 0.9943 - val_loss: 1.4596 - val_accuracy: 0.5400
# Epoch 149/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0600 - accuracy: 0.9829 - val_loss: 1.4556 - val_accuracy: 0.5300
# Epoch 150/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0490 - accuracy: 0.9929 - val_loss: 1.4545 - val_accuracy: 0.5300
# 7/7 [==============================] - 1s 146ms/step - loss: 1.4859 - accuracy: 0.5500
# Test loss:  1.4858899116516113
# Test accuracy:  0.550000011920929
# acc 0.55

# %% [markdown]
# ## 2 Layers CNN model

# %%
width,height,dimenstion = data.Xtrain[0].shape

# %%
# Defining the black box model
class CNNModel:
    def __init__(self):
        self.model = None
        self.model_name = "2layersCNN_ADAM_crossEn_mfcc_ADAM_CrossEnt"
        self.model_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + ".h5"
        self.model_weights_path = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+  self.model_name + "_weights.h5"
        self.model_history_path_acc = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_acc.png"
        self.model_history_path_loss = "/content/drive/MyDrive/Mymodels_result/" + self.model_name +"/"+ self.model_name + "_history_loss.png"
        
        self.model_history = None
    
    def build_model(self):
        """
        This function is used to create the black box model :
        """
        # Defining the input layer
        
        model = Sequential()

        #Adding the CNN layers along with some drop outs and maxpooling
        
        model.add(Conv2D(64, (3,3), activation ='relu', input_shape =(width,height,dimenstion)))
        model.add(MaxPooling2D(pool_size = (2,2)))


        model.add(Conv2D(32, (3,3),strides=(1,1) , activation = 'relu'))
        model.add(MaxPooling2D(pool_size = (2,2)))
        
        model.add(Flatten())

        
        #Adding the dense layers
        model.add(Dense(256, activation = 'relu'))
        model.add(Dropout(0.5))
        model.add(Dense(124, activation = 'relu'))
        #final output layer with 10 predictions to be made
        model.add(Dense(10, activation = 'softmax'))
    
        
        
        # Compiling the model
        self.model = model
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001), loss='categorical_crossentropy', metrics=['accuracy'])

    def train_model(self,data, epochs=10):
        """
        This function is used to train the black box model :
        """
        # Training the model
        self.model_history = self.model.fit(data.Xtrain,data.ytrain, epochs=epochs,validation_data=(data.Xval,data.yval), shuffle=True)
        
    def save_model(self):
        """
        This function is used to save the black box model :
        """
        # Save the model
        self.model.save(self.model_path)
        
    def load_model(self):
        """
        This function is used to load the black box model :
        """
        # Load the model
        self.model = tf.keras.models.load_model(self.model_path)
        
    def save_model_weights(self):
        """
        This function is used to save the weights of the black box model :
        """
        # Save the weights
        self.model.save_weights(self.model_weights_path)
    

    def evaluate_model(self, Xtest,ytest):
        """
        This function is used to evaluate the black box model :
        """
        # Evaluate the model
        test_loss, test_acc = self.model.evaluate(Xtest,ytest)
        print("Test loss: ", test_loss)
        print("Test accuracy: ", test_acc)
    
    def plot_model_history(self):
        """
        This function is used to plot the model history :
        """
        #define variables
        loss = self.model_history.history['loss']
        val_loss = self.model_history.history['val_loss']
        accuracy = self.model_history.history['accuracy']
        val_accuracy = self.model_history.history['val_accuracy']
        epochs = range(1, len(loss) + 1)
        # Plot the model history
        plt.figure()
        plt.plot(epochs, accuracy, label='Training accuracy')
        plt.plot(epochs, val_accuracy, label='Validation accuracy')
        plt.title('Training and validation accuracy')
        plt.legend()
        plt.savefig(self.model_history_path_acc)
        plt.show()

        plt.figure()
        plt.plot(epochs, loss, label='Training loss')
        plt.plot(epochs, val_loss, label='Validation loss')
        plt.title('Training and validation loss')
        plt.legend()
        plt.savefig(self.model_history_path_loss)
        plt.show()
        
    def predict_class(self, spectrogram_image):
        """
        This function is used to predict the class of the spectrogram image :
        """
        # Predict the class
        prediction = self.model.predict(spectrogram_image)
        return np.argmax(prediction)

    def predict_classes(self, spectrogram_images):
        """
        This function is used to predict the classes of the spectrogram images :
        """
        # Predict the classes
        predictions = self.model.predict(spectrogram_images)
        return np.argmax(predictions, axis=1)

    
    def plot_confusion_matrix(self, Xtest,ytest, classes=None):
        """
        This function is used to plot the confusion matrix :
        """
        # Predict the classes
        predictions = self.predict_classes(Xtest)
        # Plot the confusion matrix
        y_parse = np.argmax(ytest, axis=1)
        cm = confusion_matrix(y_parse, predictions)
        #if classes is None:
        #    classes = test_generator.class_indices.keys()
        plt.figure()
        plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
        plt.title("Confusion matrix")
        plt.colorbar()
        tick_marks = np.arange(10)
        plt.xticks(tick_marks,classes,  rotation=45)
        plt.yticks(tick_marks,classes)
        fmt = 'd'
        thresh = cm.max() / 2.
        for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
            plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="white" if cm[i, j] > thresh else "black")
        plt.ylabel('True label')
        plt.xlabel('Predicted label')
        plt.tight_layout()
        plt.savefig("/content/drive/MyDrive/Mymodels_result/"+ self.model_name +"/"+"confusion_matrix.png")
        plt.show()
        acc = np.diag(cm).sum() /cm.sum()
        print("acc",acc)

# %%
for i in range(1):
    
    # Fetch the training and test dataset
    
    # Create the  model
    model = CNNModel()
    
    # Build the  model
    model.build_model()
    # Train the  model
    model.train_model(data, epochs=150)
    
    # Save the  model
    model.save_model()

    # Evaluate  model
    model.evaluate_model(data.Xtest,data.ytest)

    # Plot the model history
    model.plot_model_history()
    
    # Plot the confusion matrix
    model.plot_confusion_matrix(data.Xtest,data.ytest)
150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.5888 - accuracy: 0.8871 - val_loss: 1.3631 - val_accuracy: 0.5100
# Epoch 46/150
# 22/22 [==============================] - 6s 270ms/step - loss: 0.5835 - accuracy: 0.8714 - val_loss: 1.3377 - val_accuracy: 0.5300
# Epoch 47/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.5156 - accuracy: 0.9243 - val_loss: 1.3297 - val_accuracy: 0.5000
# Epoch 48/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.5429 - accuracy: 0.8843 - val_loss: 1.3546 - val_accuracy: 0.4800
# Epoch 49/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.4798 - accuracy: 0.9200 - val_loss: 1.3446 - val_accuracy: 0.5300
# Epoch 50/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.4661 - accuracy: 0.9129 - val_loss: 1.3504 - val_accuracy: 0.5100
# Epoch 51/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.4792 - accuracy: 0.9271 - val_loss: 1.3336 - val_accuracy: 0.5200
# Epoch 52/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.4202 - accuracy: 0.9371 - val_loss: 1.3138 - val_accuracy: 0.5200
# Epoch 53/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.4277 - accuracy: 0.9300 - val_loss: 1.2954 - val_accuracy: 0.5300
# Epoch 54/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.4160 - accuracy: 0.9371 - val_loss: 1.3148 - val_accuracy: 0.5200
# Epoch 55/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.4114 - accuracy: 0.9443 - val_loss: 1.3343 - val_accuracy: 0.5000
# Epoch 56/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.4158 - accuracy: 0.9229 - val_loss: 1.2976 - val_accuracy: 0.5400
# Epoch 57/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.3574 - accuracy: 0.9500 - val_loss: 1.3483 - val_accuracy: 0.4800
# Epoch 58/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.3735 - accuracy: 0.9271 - val_loss: 1.3398 - val_accuracy: 0.5300
# Epoch 59/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.3670 - accuracy: 0.9386 - val_loss: 1.3243 - val_accuracy: 0.5200
# Epoch 60/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.3472 - accuracy: 0.9457 - val_loss: 1.2962 - val_accuracy: 0.5200
# Epoch 61/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.3229 - accuracy: 0.9471 - val_loss: 1.3247 - val_accuracy: 0.5200
# Epoch 62/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.3168 - accuracy: 0.9457 - val_loss: 1.3030 - val_accuracy: 0.5300
# Epoch 63/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.2900 - accuracy: 0.9614 - val_loss: 1.3402 - val_accuracy: 0.5000
# Epoch 64/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.2977 - accuracy: 0.9500 - val_loss: 1.2860 - val_accuracy: 0.5300
# Epoch 65/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.2776 - accuracy: 0.9643 - val_loss: 1.4016 - val_accuracy: 0.5200
# Epoch 66/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.2973 - accuracy: 0.9529 - val_loss: 1.2911 - val_accuracy: 0.5300
# Epoch 67/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.2382 - accuracy: 0.9771 - val_loss: 1.2852 - val_accuracy: 0.5300
# Epoch 68/150
# 22/22 [==============================] - 6s 271ms/step - loss: 0.2576 - accuracy: 0.9643 - val_loss: 1.3078 - val_accuracy: 0.5000
# Epoch 69/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.2446 - accuracy: 0.9614 - val_loss: 1.3036 - val_accuracy: 0.5200
# Epoch 70/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0
150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.1315 - accuracy: 0.9857 - val_loss: 1.3500 - val_accuracy: 0.5300
# Epoch 98/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.1262 - accuracy: 0.9800 - val_loss: 1.3257 - val_accuracy: 0.5100
# Epoch 99/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.1286 - accuracy: 0.9829 - val_loss: 1.3605 - val_accuracy: 0.5400
# Epoch 100/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.1242 - accuracy: 0.9814 - val_loss: 1.3824 - val_accuracy: 0.5300
# Epoch 101/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.1225 - accuracy: 0.9871 - val_loss: 1.3390 - val_accuracy: 0.5300
# Epoch 102/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.1135 - accuracy: 0.9843 - val_loss: 1.3855 - val_accuracy: 0.5400
# Epoch 103/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0913 - accuracy: 0.9929 - val_loss: 1.4404 - val_accuracy: 0.5200
# Epoch 104/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.1058 - accuracy: 0.9886 - val_loss: 1.3433 - val_accuracy: 0.5400
# Epoch 105/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.1065 - accuracy: 0.9843 - val_loss: 1.3999 - val_accuracy: 0.5400
# Epoch 106/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0998 - accuracy: 0.9886 - val_loss: 1.3717 - val_accuracy: 0.5400
# Epoch 107/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0898 - accuracy: 0.9886 - val_loss: 1.3611 - val_accuracy: 0.5400
# Epoch 108/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0962 - accuracy: 0.9886 - val_loss: 1.3966 - val_accuracy: 0.5000
# Epoch 109/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0932 - accuracy: 0.9886 - val_loss: 1.3909 - val_accuracy: 0.5100
# Epoch 110/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0998 - accuracy: 0.9857 - val_loss: 1.3430 - val_accuracy: 0.5400
# Epoch 111/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0983 - accuracy: 0.9914 - val_loss: 1.3982 - val_accuracy: 0.5600
# Epoch 112/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0891 - accuracy: 0.9914 - val_loss: 1.3966 - val_accuracy: 0.5300
# Epoch 113/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0751 - accuracy: 0.9929 - val_loss: 1.4507 - val_accuracy: 0.5200
# Epoch 114/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0919 - accuracy: 0.9843 - val_loss: 1.4150 - val_accuracy: 0.5100
# Epoch 115/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0933 - accuracy: 0.9886 - val_loss: 1.3797 - val_accuracy: 0.5100
# Epoch 116/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0988 - accuracy: 0.9914 - val_loss: 1.4860 - val_accuracy: 0.5100
# Epoch 117/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0789 - accuracy: 0.9957 - val_loss: 1.3543 - val_accuracy: 0.5400
# Epoch 118/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0770 - accuracy: 0.9943 - val_loss: 1.4503 - val_accuracy: 0.5100
# Epoch 119/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0728 - accuracy: 0.9929 - val_loss: 1.4307 - val_accuracy: 0.5500
# Epoch 120/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0783 - accuracy: 0.9886 - val_loss: 1.4336 - val_accuracy: 0.5300
# Epoch 121/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0623 - accuracy: 0.9971 - val_loss: 1.3911 - val_accuracy: 0.5400
# Epoch 122/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0753 - accuracy: 0.9900 - val_loss: 1.3462 - val_accuracy: 0.5400
# Epoch 123/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0797 - accuracy: 0.9929 - val_loss: 1.4128 - val_accuracy: 0.5300
# Epoch 124/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0799 - accuracy: 0.9829 - val_loss: 1.3953 - val_accuracy: 0.5200
# Epoch 125/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0733 - accuracy: 0.9871 - val_loss: 1.5351 - val_accuracy: 0.5100
# Epoch 126/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0871 - accuracy: 0.9886 - val_loss: 1.4138 - val_accuracy: 0.5300
# Epoch 127/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0766 - accuracy: 0.9886 - val_loss: 1.4683 - val_accuracy: 0.5500
# Epoch 128/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0727 - accuracy: 0.9929 - val_loss: 1.4104 - val_accuracy: 0.5300
# Epoch 129/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0873 - accuracy: 0.9900 - val_loss: 1.4583 - val_accuracy: 0.5200
# Epoch 130/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0781 - accuracy: 0.9871 - val_loss: 1.3892 - val_accuracy: 0.5600
# Epoch 131/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0634 - accuracy: 0.9943 - val_loss: 1.4088 - val_accuracy: 0.5200
# Epoch 132/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0782 - accuracy: 0.9857 - val_loss: 1.4011 - val_accuracy: 0.5100
# Epoch 133/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0733 - accuracy: 0.9914 - val_loss: 1.4355 - val_accuracy: 0.5300
# Epoch 134/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0583 - accuracy: 0.9929 - val_loss: 1.4595 - val_accuracy: 0.5400
# Epoch 135/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0555 - accuracy: 0.9943 - val_loss: 1.5228 - val_accuracy: 0.5300
# Epoch 136/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0813 - accuracy: 0.9871 - val_loss: 1.5430 - val_accuracy: 0.5300
# Epoch 137/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0685 - accuracy: 0.9914 - val_loss: 1.3874 - val_accuracy: 0.5300
# Epoch 138/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0548 - accuracy: 0.9914 - val_loss: 1.4891 - val_accuracy: 0.5300
# Epoch 139/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0536 - accuracy: 0.9929 - val_loss: 1.5030 - val_accuracy: 0.5300
# Epoch 140/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0627 - accuracy: 0.9900 - val_loss: 1.4426 - val_accuracy: 0.4900
# Epoch 141/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0567 - accuracy: 0.9914 - val_loss: 1.3889 - val_accuracy: 0.5300
# Epoch 142/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0699 - accuracy: 0.9914 - val_loss: 1.3863 - val_accuracy: 0.5400
# Epoch 143/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0727 - accuracy: 0.9900 - val_loss: 1.4366 - val_accuracy: 0.5200
# Epoch 144/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0578 - accuracy: 0.9943 - val_loss: 1.4525 - val_accuracy: 0.5300
# Epoch 145/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0556 - accuracy: 0.9900 - val_loss: 1.4816 - val_accuracy: 0.5200
# Epoch 146/150
# 22/22 [==============================] - 6s 272ms/step - loss: 0.0571 - accuracy: 0.9914 - val_loss: 1.5086 - val_accuracy: 0.5400
# Epoch 147/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0544 - accuracy: 0.9929 - val_loss: 1.4376 - val_accuracy: 0.5200
# Epoch 148/150
# 22/22 [==============================] - 6s 275ms/step - loss: 0.0456 - accuracy: 0.9943 - val_loss: 1.4596 - val_accuracy: 0.5400
# Epoch 149/150
# 22/22 [==============================] - 6s 274ms/step - loss: 0.0600 - accuracy: 0.9829 - val_loss: 1.4556 - val_accuracy: 0.5300
# Epoch 150/150
# 22/22 [==============================] - 6s 273ms/step - loss: 0.0490 - accuracy: 0.9929 - val_loss: 1.4545 - val_accuracy: 0.5300
# 7/7 [==============================] - 1s 146ms/step - loss: 1.4859 - accuracy: 0.5500
# Test loss:  1.4858899116516113
# Test accuracy:  0.550000011920929
# acc 0.55
